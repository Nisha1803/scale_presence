# %%
import pandas as pd
import numpy as np
import sklearn
import matplotlib
import sys

print("Python version:", sys.version)
print("pandas version:", pd.__version__)
print("numpy version:", np.__version__)
print("scikit-learn version:", sklearn.__version__)
print("matplotlib version:", matplotlib.__version__)
# Out:
# Python version: 3.13.5 (tags/v3.13.5:6cb20a2, Jun 11 2025, 16:15:46) [MSC v.1943 64 bit (AMD64)]
# pandas version: 2.3.1
# numpy version: 2.3.1
# scikit-learn version: 1.7.1
# matplotlib version: 3.10.3

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    roc_auc_score, precision_score, recall_score, f1_score
)
from sklearn.utils import resample
# import ace_tools as tools

# %%
# Reload with correct dataset
df = pd.read_csv("RCS_data_06_23_2025.csv")

# Define survey columns
survey_columns = [c for c in df.columns if c.startswith("RCS_Inferred_")]

# Base excluded columns (fixed exclusions)
base_excluded_cols = [
    "Survey_2017", "Survey_2021", "Survey_2022", "Survey_2023", "Survey_2024",
    "Water_Presence", "water_saturation"
]+ survey_columns

# Dynamic columns to exclude one-by-one
dynamic_excluded_candidates = [
    "Assumed_Presence", "Inferred_Phrag_Presence", "Phragmites_Presence",
    "Xmax", "MaxEnt_Phragmites", "Xmin", "GridSquare", "MaxEnt_RCS_cold_native""MaxEnt_RCS_cold_native","Ymin","Ymax","MaxEnt_Nipponaclerda", "MaxEnt_RCS_native","NRI_RISK_SCORE", "NRI_HRCN_RISKS",
    "NRI_EAL_SCORE","Yellowthroat_breeding",
    "NRI_SOVI_SCORE",                         
    "NRI_RESL_SCORE",                         
    "NRI_RFLD_RISKS",                         
    "NRI_TRND_RISKS",                         
    "Wren_breeding",                          
    "Wren_postbreeding_migration"  
]

# Append survey columns to dynamic exclusion
all_dynamic_excluded = dynamic_excluded_candidates 

# Define target
target_col = "RCS_Inferred_2021"
df = df[df[target_col] != -50].copy()
df["Presence"] = (df[target_col] > 0).astype(int)

# Parameters
n_iterations = 10
base_seed = 42

# Store results
results = []

for i in range(1, len(all_dynamic_excluded) + 1):
    current_excluded = base_excluded_cols + all_dynamic_excluded[:i]
    feature_cols = [c for c in df.columns if c not in current_excluded + ["Presence", target_col]]

    if not feature_cols:
        continue

    aucs, precisions, recalls, f1s = [], [], [], []

    for j in range(n_iterations):
        seed = base_seed + j
        df_majority = df[df.Presence == 0]
        df_minority = df[df.Presence == 1]
        df_maj_down = resample(df_majority, replace=False, n_samples=len(df_minority), random_state=seed)
        df_balanced = pd.concat([df_maj_down, df_minority]).sample(frac=1, random_state=seed)

        X = df_balanced[feature_cols]
        y = df_balanced["Presence"]
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=seed)

        rf = RandomForestClassifier(n_estimators=100, random_state=seed)
        rf.fit(X_train, y_train)

        y_prob = rf.predict_proba(X_test)[:, 1]
        y_pred = rf.predict(X_test)

        aucs.append(roc_auc_score(y_test, y_prob))
        precisions.append(precision_score(y_test, y_pred))
        recalls.append(recall_score(y_test, y_pred))
        f1s.append(f1_score(y_test, y_pred))

    feat_imp = pd.Series(rf.feature_importances_, index=feature_cols).sort_values(ascending=False)

    result_entry = {
        "Excluded_Features": all_dynamic_excluded[:i],
        "Num_Features": len(feature_cols),
        "AUC_Mean": np.mean(aucs),
        "AUC_Std": np.std(aucs),
        "Precision_Mean": np.mean(precisions),
        "Recall_Mean": np.mean(recalls),
        "F1_Mean": np.mean(f1s),
    }

    # Add top 15 features dynamically
    for rank in range(15):
        feat_name = feat_imp.index[rank] if rank < len(feat_imp) else None
        feat_value = feat_imp.iloc[rank] if rank < len(feat_imp) else None
        result_entry[f"Top_Feature_{rank+1}"] = feat_name
        result_entry[f"Importance_{rank+1}"] = feat_value

    results.append(result_entry)

results_df = pd.DataFrame(results)
print(results_df)
results_df.to_csv("2021_excluded_feature_impact_summary.csv", index=False)
# Out:
#                                     Excluded_Features  Num_Features  AUC_Mean  \
# 0                                  [Assumed_Presence]            30  1.000000
# 1         [Assumed_Presence, Inferred_Phrag_Presence]            29  0.810569
# 2   [Assumed_Presence, Inferred_Phrag_Presence, Ph...            28  0.810656
# 3   [Assumed_Presence, Inferred_Phrag_Presence, Ph...            27  0.806039
# 4   [Assumed_Presence, Inferred_Phrag_Presence, Ph...            26  0.806678
# 5   [Assumed_Presence, Inferred_Phrag_Presence, Ph...            25  0.801829
# 6   [Assumed_Presence, Inferred_Phrag_Presence, Ph...            24  0.799768
# 7   [Assumed_Presence, Inferred_Phrag_Presence, Ph...            24  0.799768
# 8   [Assumed_Presence, Inferred_Phrag_Presence, Ph...            23  0.799274
# 9   [Assumed_Presence, Inferred_Phrag_Presence, Ph...            22  0.780314
# 10  [Assumed_Presence, Inferred_Phrag_Presence, Ph...            21  0.771835
# 11  [Assumed_Presence, Inferred_Phrag_Presence, Ph...            20  0.740621
# 12  [Assumed_Presence, Inferred_Phrag_Presence, Ph...            19  0.741347
# 13  [Assumed_Presence, Inferred_Phrag_Presence, Ph...            18  0.738269
# 14  [Assumed_Presence, Inferred_Phrag_Presence, Ph...            17  0.734495
# 15  [Assumed_Presence, Inferred_Phrag_Presence, Ph...            16  0.735366
# 16  [Assumed_Presence, Inferred_Phrag_Presence, Ph...            15  0.733740
# 17  [Assumed_Presence, Inferred_Phrag_Presence, Ph...            14  0.732956
# 18  [Assumed_Presence, Inferred_Phrag_Presence, Ph...            13  0.730372
# 19  [Assumed_Presence, Inferred_Phrag_Presence, Ph...            12  0.620528
# 20  [Assumed_Presence, Inferred_Phrag_Presence, Ph...            11  0.579617
# 21  [Assumed_Presence, Inferred_Phrag_Presence, Ph...            10  0.574361
#
#          AUC_Std  Precision_Mean  Recall_Mean   F1_Mean  \
# 0   3.510833e-17        0.995349     1.000000  0.997619
# 1   5.366341e-02        0.739180     0.711847  0.723913
# 2   4.739872e-02        0.742779     0.714228  0.726826
# 3   5.258869e-02        0.734975     0.702091  0.717082
# 4   4.796565e-02        0.740203     0.702149  0.719028
# 5   4.861363e-02        0.746259     0.711905  0.726685
# 6   5.135224e-02        0.732719     0.699652  0.713971
# 7   5.135224e-02        0.732719     0.699652  0.713971
# 8   4.115090e-02        0.731509     0.687631  0.706936
# 9   3.941956e-02        0.718567     0.680488  0.697470
# 10  3.730235e-02        0.696328     0.680430  0.687026
# 11  4.556878e-02        0.655538     0.639082  0.645896
# 12  4.431047e-02        0.653546     0.634262  0.642397
# 13  4.677469e-02        0.650429     0.639082  0.643420
# 14  4.773473e-02        0.648151     0.634204  0.639659
# 15  5.296715e-02        0.643022     0.627003  0.633138
# 16  5.225013e-02        0.643447     0.629384  0.634474
# 17  5.258436e-02        0.643292     0.631823  0.635873
# 18  5.889490e-02        0.640051     0.634321  0.635242
# 19  6.632874e-02        0.583172     0.571429  0.575827
# 20  6.527198e-02        0.545090     0.520674  0.531652
# 21  6.510303e-02        0.543720     0.520674  0.530983
#
#               Top_Feature_1  Importance_1                Top_Feature_2  ...  \
# 0   Inferred_Phrag_Presence      0.597374                         Xmax  ...
# 1                      Xmin      0.110674                         Xmax  ...
# 2                      Xmax      0.116995                         Xmin  ...
# 3                      Xmin      0.133190            MaxEnt_Phragmites  ...
# 4                      Xmin      0.142868                   GridSquare  ...
# 5    MaxEnt_RCS_cold_native      0.134818                   GridSquare  ...
# 6         MaxEnt_RCS_native      0.143924       MaxEnt_RCS_cold_native  ...
# 7         MaxEnt_RCS_native      0.143924       MaxEnt_RCS_cold_native  ...
# 8                      Ymax      0.190321       MaxEnt_RCS_cold_native  ...
# 9    MaxEnt_RCS_cold_native      0.245762            MaxEnt_RCS_native  ...
# 10   MaxEnt_RCS_cold_native      0.345683            MaxEnt_RCS_native  ...
# 11   MaxEnt_RCS_cold_native      0.666840               NRI_RISK_SCORE  ...
# 12   MaxEnt_RCS_cold_native      0.663339               NRI_HRCN_RISKS  ...
# 13   MaxEnt_RCS_cold_native      0.666562                NRI_EAL_SCORE  ...
# 14   MaxEnt_RCS_cold_native      0.669307               NRI_RESL_SCORE  ...
# 15   MaxEnt_RCS_cold_native      0.677072               NRI_RESL_SCORE  ...
# 16   MaxEnt_RCS_cold_native      0.671988               NRI_RESL_SCORE  ...
# 17   MaxEnt_RCS_cold_native      0.676386               NRI_TRND_RISKS  ...
# 18   MaxEnt_RCS_cold_native      0.700017               NRI_TRND_RISKS  ...
# 19   MaxEnt_RCS_cold_native      0.969730                Wren_breeding  ...
# 20   MaxEnt_RCS_cold_native      0.989229  Wren_postbreeding_migration  ...
# 21   MaxEnt_RCS_cold_native      0.997661   Wren_prebreeding_migration  ...
#
#                          Top_Feature_11 Importance_11  \
# 0                  MaxEnt_Nipponaclerda      0.025122
# 1                         NRI_EAL_SCORE      0.044949
# 2                        NRI_RISK_SCORE      0.048342
# 3                        NRI_HRCN_RISKS      0.032210
# 4                        NRI_SOVI_SCORE      0.024419
# 5                        NRI_RESL_SCORE      0.024134
# 6                        NRI_RFLD_RISKS      0.025730
# 7                        NRI_RFLD_RISKS      0.025730
# 8                        NRI_TRND_RISKS      0.024009
# 9                 Yellowthroat_breeding      0.022143
# 10                Yellowthroat_breeding      0.019878
# 11          Wren_postbreeding_migration      0.007777
# 12           Wren_prebreeding_migration      0.000548
# 13   Yellowthroat_prebreeding_migration      0.000110
# 14  Yellowthroat_postbreeding_migration      0.000000
# 15             Yellowthroat_nonbreeding      0.000000
# 16             Yellowthroat_nonbreeding      0.000000
# 17     Blackbird_postbreeding_migration      0.000000
# 18                   Blackbird_breeding      0.000000
# 19     Blackbird_postbreeding_migration      0.000000
# 20      Blackbird_prebreeding_migration      0.000000
# 21                                 None           NaN
#
#                         Top_Feature_12 Importance_12  \
# 0                        NRI_EAL_SCORE      0.021350
# 1                       NRI_HRCN_RISKS      0.033207
# 2                       NRI_HRCN_RISKS      0.033832
# 3                       NRI_SOVI_SCORE      0.022302
# 4                       NRI_RESL_SCORE      0.022310
# 5                       NRI_RFLD_RISKS      0.020330
# 6                       NRI_TRND_RISKS      0.022187
# 7                       NRI_TRND_RISKS      0.022187
# 8                        Wren_breeding      0.018638
# 9                        Wren_breeding      0.021477
# 10         Wren_postbreeding_migration      0.005053
# 11          Wren_prebreeding_migration      0.000267
# 12  Yellowthroat_prebreeding_migration      0.000205
# 13                    Wren_nonbreeding      0.000000
# 14            Yellowthroat_nonbreeding      0.000000
# 15                    Wren_nonbreeding      0.000000
# 16     Blackbird_prebreeding_migration      0.000000
# 17               Blackbird_nonbreeding      0.000000
# 18     Blackbird_prebreeding_migration      0.000000
# 19     Blackbird_prebreeding_migration      0.000000
# 20                                None           NaN
# 21                                None           NaN
#
#                          Top_Feature_13 Importance_13  \
# 0                     MaxEnt_RCS_native      0.018908
# 1                        NRI_SOVI_SCORE      0.023077
# 2                        NRI_RESL_SCORE      0.022690
# 3                        NRI_RESL_SCORE      0.020203
# 4                        NRI_TRND_RISKS      0.019849
# 5                        NRI_TRND_RISKS      0.019999
# 6                         Wren_breeding      0.017132
# 7                         Wren_breeding      0.017132
# 8                 Yellowthroat_breeding      0.012454
# 9           Wren_postbreeding_migration      0.004767
# 10           Wren_prebreeding_migration      0.000085
# 11   Yellowthroat_prebreeding_migration      0.000113
# 12                     Wren_nonbreeding      0.000000
# 13  Yellowthroat_postbreeding_migration      0.000000
# 14                     Wren_nonbreeding      0.000000
# 15                   Blackbird_breeding      0.000000
# 16     Blackbird_postbreeding_migration      0.000000
# 17                   Blackbird_breeding      0.000000
# 18     Blackbird_postbreeding_migration      0.000000
# 19                                 None           NaN
# 20                                 None           NaN
# 21                                 None           NaN
#
#                         Top_Feature_14 Importance_14  \
# 0                       NRI_SOVI_SCORE      0.009174
# 1                  Phragmites_Presence      0.020646
# 2                       NRI_TRND_RISKS      0.021687
# 3                       NRI_TRND_RISKS      0.018317
# 4                       NRI_RFLD_RISKS      0.018871
# 5                        Wren_breeding      0.014718
# 6                Yellowthroat_breeding      0.003963
# 7                Yellowthroat_breeding      0.003963
# 8          Wren_postbreeding_migration      0.003599
# 9   Yellowthroat_prebreeding_migration      0.000114
# 10  Yellowthroat_prebreeding_migration      0.000040
# 11                    Wren_nonbreeding      0.000000
# 12    Blackbird_postbreeding_migration      0.000000
# 13            Yellowthroat_nonbreeding      0.000000
# 14                  Blackbird_breeding      0.000000
# 15     Blackbird_prebreeding_migration      0.000000
# 16               Blackbird_nonbreeding      0.000000
# 17     Blackbird_prebreeding_migration      0.000000
# 18                                None           NaN
# 19                                None           NaN
# 20                                None           NaN
# 21                                None           NaN
#
#                          Top_Feature_15 Importance_15
# 0                   Phragmites_Presence      0.008769
# 1                        NRI_RESL_SCORE      0.019814
# 2                        NRI_SOVI_SCORE      0.018020
# 3                        NRI_RFLD_RISKS      0.017547
# 4                         Wren_breeding      0.008974
# 5                 Yellowthroat_breeding      0.005860
# 6           Wren_postbreeding_migration      0.003839
# 7           Wren_postbreeding_migration      0.003839
# 8            Wren_prebreeding_migration      0.000177
# 9            Wren_prebreeding_migration      0.000042
# 10                     Wren_nonbreeding      0.000000
# 11      Blackbird_prebreeding_migration      0.000000
# 12  Yellowthroat_postbreeding_migration      0.000000
# 13                Blackbird_nonbreeding      0.000000
# 14      Blackbird_prebreeding_migration      0.000000
# 15                Blackbird_nonbreeding      0.000000
# 16                   Blackbird_breeding      0.000000
# 17                                 None           NaN
# 18                                 None           NaN
# 19                                 None           NaN
# 20                                 None           NaN
# 21                                 None           NaN
#
# [22 rows x 37 columns]
